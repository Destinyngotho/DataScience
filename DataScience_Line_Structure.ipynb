# %% [markdown]
# <a href="https://colab.research.google.com/github/Destinyngotho/DataScience/blob/main/DataScience_Line_Structure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
Year = [1920, 1930, 1940, 1959, 1960, 1970, 1980, 1990, 2000, 2010]
Unemployment_Rate = [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3]

# %%
plt.plot(Year, Unemployment_Rate, color= "purple", marker = "o")
plt.title('Unemployment Rate Vs Year', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Unemployment Rate', fontsize=14)
plt.grid(True)
plt.show()
